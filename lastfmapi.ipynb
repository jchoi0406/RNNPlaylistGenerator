# %%
from datetime import datetime, timedelta
import requests
from datetime import datetime
import pandas as pd
from dotenv import main
import os

# %%
main.load_dotenv()
api_key = os.getenv("API_KEY")
username = "write_username_here"

# %%
class LastFMAPI:
    WEEK_DIFF = 604800
    FILE_NAME = "alltracks.csv"
    def __init__(self, username, key, limit=1000):
        self.username = username
        self.key = key
        self.limit = limit
        self.start_date = datetime(year=2022, month=12, day=1)  # first time using lastfm
        self.start_utc = int(self.start_date.timestamp()) # utc
        self.dfs = []
        self.current_time = datetime.now()
        self.utc_time = int(self.current_time.timestamp())
        self.df = pd.DataFrame()
        
    def get_start_date(self):
        return self.start_utc
    
    def set_next_start_date(self):
        if self.start_utc + LastFMAPI.WEEK_DIFF > self.utc_time:
            self.start_utc = self.utc_time
        else:
            self.start_utc += LastFMAPI.WEEK_DIFF
        
    def get_end_date(self):
        return self.start_utc + LastFMAPI.WEEK_DIFF
    
    def get_tags(self, artists):  # only alphanumeric
        tags = {}
        for artist in (set(artists)):
            url = f"https://ws.audioscrobbler.com/2.0/?method=artist.getTopTags&artist={artist}&api_key={self.key}&format=json"
            res = requests.get(url).json()
            print(res)
            if 'toptags' in res and 'tag' in res['toptags'] and len(res['toptags']['tag']) > 0:
                top = res['toptags']['tag'][0]['name']
                tags[artist] = top
            else:
                print(f"Error or no tags found for artist: {artist}")
        return tags
            
        
        
    def get_and_save_all_tags(self):
        self.df['tags'] = self.get_tags_vectorized(self.df['artist'])
        self.df.to_csv(LastFMAPI.FILE_NAME, encoding="utf-8")

    def get_tags_vectorized(self, artists):
        tags_dict = self.get_tags(artists)
        return artists.map(lambda artist: tags_dict.get(artist, []))

        
    def save_tracks(self):
        url = f"https://ws.audioscrobbler.com/2.0/?api_key={self.key}&method=user.getrecenttracks&user={self.username}&from={self.get_start_date()}&to={self.get_end_date()}&limit={self.limit}&format=json"
        res = requests.get(url).json()
        tracks = res['recenttracks']["track"]
        track_name = []
        artist = []
        album_name = []
        date_listened = []
        uts = []
        urls = []
        for track in tracks:  # might be more efficient to build the dataframe by row, instead of column.
            try:
                artist.append(track['artist']['#text'])
            except KeyError:
                artist.append("NA")
            
            try:
                album_name.append(track['album']['#text'])
            except KeyError:
                album_name.append("NA")
            
            try:
                track_name.append(track['name'])
            except KeyError:
                track_name.append("NA")
            
            try:
                date_listened.append(track['date']['#text'])
            except KeyError:
                date_listened.append("NA")
            
            try:
                uts.append(track['date']['uts'])
            except KeyError:
                uts.append("NA")
            
            try:
                urls.append(track['url'])
            except KeyError:
                urls.append("NA")
            
        df = pd.DataFrame({
            'track_name': track_name,
            'artist': artist,
            'album_name': album_name,
            'date_listened': date_listened,
            'uts': uts,
            'url': urls,
        })
        self.dfs.append(df)
    def get_csv_file(self):
        merged_table = pd.concat(self.dfs, ignore_index=True)
        self.df = merged_table
        merged_table.to_csv(LastFMAPI.FILE_NAME, encoding="utf-8")
    
    def get_all_tracks(self):
        while self.get_start_date() < self.utc_time:
            self.save_tracks()
            self.set_next_start_date() 
            print("Saving..")
        print("DONE!")

# %%
lastfmapi = LastFMAPI(username, api_key)
lastfmapi.get_all_tracks()
lastfmapi.get_csv_file()
# Out:
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# Saving..
# DONE!

# %%
lastfmapi.get_and_save_all_tags()
# Out:
# {'toptags': {'tag': [{'count': 100, 'name': 'folk', 'url': 'https://www.last.fm/tag/folk'}, {'count': 90, 'name': 'Ukrainian', 'url': 'https://www.last.fm/tag/Ukrainian'}, {'count': 48, 'name': 'ethno-chaos', 'url': 'https://www.last.fm/tag/ethno-chaos'}, {'count': 30, 'name': 'seen live', 'url': 'https://www.last.fm/tag/seen+live'}, {'count': 23, 'name': 'ethnochaos', 'url': 'https://www.last.fm/tag/ethnochaos'}, {'count': 22, 'name': 'ethno chaos', 'url': 'https://www.last.fm/tag/ethno+chaos'}, {'count': 15, 'name': 'ethno', 'url': 'https://www.last.fm/tag/ethno'}, {'count': 13, 'name': 'Ukraine', 'url': 'https://www.last.fm/tag/Ukraine'}, {'count': 12, 'name': 'ethnic', 'url': 'https://www.last.fm/tag/ethnic'}, {'count': 8, 'name': 'World Music', 'url': 'https://www.last.fm/tag/World+Music'}, {'count': 6, 'name': 'world', 'url': 'https://www.last.fm/tag/world'}, {'count': 5, 'name': 'neofolk', 'url': 'https://www.last.fm/tag/neofolk'}, {'count': 5, 'name': 'electronic folk', 'url': 'https://www.last.fm/tag/electronic+folk'}, {'count': 3, 'name': 'contemporary folk', 'url': 'https://www.last.fm/tag/contemporary+folk'}, {'count': 3, 'name': 'throat singing', 'url': 'https://www.last.fm/tag/throat+singing'}, {'count': 3, 'name': 'freak folk', 'url': 'https://www.last.fm/tag/freak+folk'}, {'count': 3, 'name': 'folk pop', 'url': 'https://www.last.fm/tag/folk+pop'}, {'count': 3, 'name': 'world fusion', 'url': 'https://www.last.fm/tag/world+fusion'}, {'count': 3, 'name': 'traditional folk', 'url': 'https://www.last.fm/tag/traditional+folk'}, {'count': 3, 'name': 'ukrainian folk', 'url': 'https://www.last.fm/tag/ukrainian+folk'}, {'count': 3, 'name': 'Ukrainian folk music', 'url': 'https://www.last.fm/tag/Ukrainian+folk+music'}, {'count': 3, 'name': 'ukrainskt', 'url': 'https://www.last.fm/tag/ukrainskt'}, {'count': 2, 'name': 'electronic', 'url': 'https://www.last.fm/tag/electronic'}, {'count': 2, 'name': 'vocal', 'url': 'https://www.last.fm/tag/vocal'}, {'count': 2, 'name': 'jazz', 'url': 'https://www.last.fm/tag/jazz'}, {'count': 2, 'name': 'alternative', 'url': 'https://www.last.fm/tag/alternative'}, {'count': 2, 'name': 'experimental', 'url': 'https://www.last.fm/tag/experimental'}, {'count': 2, 'name': 'female vocalists', 'url': 'https://www.last.fm/tag/female+vocalists'}, {'count': 2, 'name': 'piano', 'url': 'https://www.last.fm/tag/piano'}, {'count': 2, 'name': 'abstract', 'url': 'https://www.last.fm/tag/abstract'}, {'count': 2, 'name': 'cello', 'url': 'https://www.last.fm/tag/cello'}, {'count': 2, 'name': 'weird', 'url': 'https://www.last.fm/tag/weird'}, {'count': 2, 'name': 'trombone', 'url': 'https://www.last.fm/tag/trombone'}, {'count': 2, 'name': 'ethereal', 'url': 'https://www.last.fm/tag/ethereal'}, {'count': 2, 'name': 'percussion', 'url': 'https://www.last.fm/tag/percussion'}, {'count': 2, 'name': 'Pagan', 'url': 'https://www.last.fm/tag/Pagan'}, {'count': 2, 'name': 'traditional', 'url': 'https://www.last.fm/tag/traditional'}, {'count': 2, 'name': '2', 'url': 'https://www.last.fm/tag/2'}, {'count': 2, 'name': 'accordion', 'url': 'https://www.last.fm/tag/accordion'}, {'count': 2, 'name': 'european', 'url': 'https://www.last.fm/tag/european'}, {'count': 2, 'name': 'Sardinia', 'url': 'https://www.last.fm/tag/Sardinia'}, {'count': 2, 'name': 'Great Music', 'url': 'https://www.last.fm/tag/Great+Music'}, {'count': 2, 'name': 'didgeridoo', 'url': 'https://www.last.fm/tag/didgeridoo'}, {'count': 2, 'name': 'djembe', 'url': 'https://www.last.fm/tag/djembe'}, {'count': 2, 'name': 'darbuka', 'url': 'https://www.last.fm/tag/darbuka'}, {'count': 2, 'name': 'worldmusic', 'url': 'https://www.last.fm/tag/worldmusic'}, {'count': 2, 'name': 'experimental folk', 'url': 'https://www.last.fm/tag/experimental+folk'}, {'count': 2, 'name': 'eastern european folk', 'url': 'https://www.last.fm/tag/eastern+european+folk'}, {'count': 2, 'name': 'etno', 'url': 'https://www.last.fm/tag/etno'}, {'count': 2, 'name': 'hard folk', 'url': 'https:// ...
# {'toptags': {'tag': [{'count': 100, 'name': 'dancehall', 'url': 'https://www.last.fm/tag/dancehall'}, {'count': 94, 'name': 'reggae', 'url': 'https://www.last.fm/tag/reggae'}, {'count': 60, 'name': 'Hip-Hop', 'url': 'https://www.last.fm/tag/Hip-Hop'}, {'count': 38, 'name': 'rnb', 'url': 'https://www.last.fm/tag/rnb'}, {'count': 35, 'name': 'rap', 'url': 'https://www.last.fm/tag/rap'}, {'count': 13, 'name': 'hip hop', 'url': 'https://www.last.fm/tag/hip+hop'}, {'count': 12, 'name': 'dance', 'url': 'https://www.last.fm/tag/dance'}, {'count': 11, 'name': 'Sean Paul', 'url': 'https://www.last.fm/tag/Sean+Paul'}, {'count': 10, 'name': 'seen live', 'url': 'https://www.last.fm/tag/seen+live'}, {'count': 9, 'name': 'pop', 'url': 'https://www.last.fm/tag/pop'}, {'count': 7, 'name': 'jamaica', 'url': 'https://www.last.fm/tag/jamaica'}, {'count': 7, 'name': 'ragga', 'url': 'https://www.last.fm/tag/ragga'}, {'count': 7, 'name': 'jamaican', 'url': 'https://www.last.fm/tag/jamaican'}, {'count': 5, 'name': 'Reggaeton', 'url': 'https://www.last.fm/tag/Reggaeton'}, {'count': 4, 'name': 'male vocalists', 'url': 'https://www.last.fm/tag/male+vocalists'}, {'count': 3, 'name': 'hiphop', 'url': 'https://www.last.fm/tag/hiphop'}, {'count': 2, 'name': 'rock', 'url': 'https://www.last.fm/tag/rock'}, {'count': 2, 'name': 'electronic', 'url': 'https://www.last.fm/tag/electronic'}, {'count': 2, 'name': 'soul', 'url': 'https://www.last.fm/tag/soul'}, {'count': 2, 'name': '00s', 'url': 'https://www.last.fm/tag/00s'}, {'count': 2, 'name': 'alternative', 'url': 'https://www.last.fm/tag/alternative'}, {'count': 2, 'name': 'r&b', 'url': 'https://www.last.fm/tag/r&b'}, {'count': 2, 'name': 'dance hall', 'url': 'https://www.last.fm/tag/dance+hall'}, {'count': 2, 'name': 'dancehall reggae', 'url': 'https://www.last.fm/tag/dancehall+reggae'}, {'count': 2, 'name': 'electronica', 'url': 'https://www.last.fm/tag/electronica'}, {'count': 1, 'name': 'urban', 'url': 'https://www.last.fm/tag/urban'}], '@attr': {'artist': 'Sean Paul'}}}
# {'toptags': {'tag': [{'count': 100, 'name': 'funk', 'url': 'https://www.last.fm/tag/funk'}, {'count': 88, 'name': 'soul', 'url': 'https://www.last.fm/tag/soul'}, {'count': 25, 'name': 'Disco', 'url': 'https://www.last.fm/tag/Disco'}, {'count': 13, 'name': 'american', 'url': 'https://www.last.fm/tag/american'}, {'count': 13, 'name': 'rnb', 'url': 'https://www.last.fm/tag/rnb'}, {'count': 13, 'name': 'los angeles', 'url': 'https://www.last.fm/tag/los+angeles'}], '@attr': {'artist': 'Earth, Wind '}}}
# {'toptags': {'tag': [{'count': 100, 'name': 'Hip-Hop', 'url': 'https://www.last.fm/tag/Hip-Hop'}, {'count': 86, 'name': 'experimental', 'url': 'https://www.last.fm/tag/experimental'}, {'count': 83, 'name': 'experimental hip-hop', 'url': 'https://www.last.fm/tag/experimental+hip-hop'}, {'count': 80, 'name': 'glitch hop', 'url': 'https://www.last.fm/tag/glitch+hop'}, {'count': 74, 'name': 'seen live', 'url': 'https://www.last.fm/tag/seen+live'}, {'count': 56, 'name': 'rap', 'url': 'https://www.last.fm/tag/rap'}, {'count': 45, 'name': 'experimental hip hop', 'url': 'https://www.last.fm/tag/experimental+hip+hop'}, {'count': 45, 'name': 'cloud rap', 'url': 'https://www.last.fm/tag/cloud+rap'}, {'count': 39, 'name': 'industrial hip hop', 'url': 'https://www.last.fm/tag/industrial+hip+hop'}, {'count': 36, 'name': 'hip hop', 'url': 'https://www.last.fm/tag/hip+hop'}, {'count': 27, 'name': 'hardcore hip hop', 'url': 'https://www.last.fm/tag/hardcore+hip+hop'}, {'count': 27, 'name': 'industrial hip-hop', 'url': 'https://www.last.fm/tag/industrial+hip-hop'}, {'count': 27, 'name': 'alternative rnb', 'url': 'https://www.last.fm/tag/alternative+rnb'}, {'count': 21, 'name': 'experimental rap', 'url': 'https://www.last.fm/tag/experimental+rap'}, {'count': 15, 'name': 'glitch', 'url': 'https://www.last.fm/tag/glitch'}, {'count': 15, 'name': 'american', 'url': 'https://www.last.fm/tag/american'}, {'count': 12, 'name': 'industrial', 'url': 'https://www.last.fm/tag/industrial'}, {'count': 12, 'name': 'alternative hip-hop', 'url': 'https://www.last.fm/tag/alternative+hip-hop'}, {'count': 12, 'name': 'trap', 'url': 'https://www.last.fm/tag/trap'}, {'count': 12, 'name': 'Political Hip Hop', 'url': 'https://www.last.fm/tag/Political+Hip+Hop'}, {'count': 9, 'name': 'electronic', 'url': 'https://www.last.fm/tag/electronic'}, {'count': 9, 'name': 'glitch-hop', 'url': 'https://www.last.fm/tag/glitch-hop'}, {'count': 9, 'name': 'alternative rap', 'url': 'https://www.last.fm/tag/alternative+rap'}, {'count': 9, 'name': 'Baltimore', 'url': 'https://www.last.fm/tag/Baltimore'}, {'count': 9, 'name': 'sound collage', 'url': 'https://www.last.fm/tag/sound+collage'}, {'count': 6, 'name': 'USA', 'url': 'https://www.last.fm/tag/USA'}, {'count': 6, 'name': 'abstract', 'url': 'https://www.last.fm/tag/abstract'}, {'count': 6, 'name': 'idm', 'url': 'https://www.last.fm/tag/idm'}, {'count': 6, 'name': 'pop rap', 'url': 'https://www.last.fm/tag/pop+rap'}, {'count': 6, 'name': 'rap metal', 'url': 'https://www.last.fm/tag/rap+metal'}, {'count': 6, 'name': 'hardcore hip-hop', 'url': 'https://www.last.fm/tag/hardcore+hip-hop'}, {'count': 6, 'name': 'industrial rap', 'url': 'https://www.last.fm/tag/industrial+rap'}, {'count': 6, 'name': 'rap rock', 'url': 'https://www.last.fm/tag/rap+rock'}, {'count': 6, 'name': 'goat', 'url': 'https://www.last.fm/tag/goat'}, {'count': 6, 'name': 'emo rap', 'url': 'https://www.last.fm/tag/emo+rap'}, {'count': 6, 'name': 'noise rap', 'url': 'https://www.last.fm/tag/noise+rap'}, {'count': 6, 'name': 'trap rap', 'url': 'https://www.last.fm/tag/trap+rap'}, {'count': 6, 'name': 'post-trap', 'url': 'https://www.last.fm/tag/post-trap'}, {'count': 6, 'name': 'JPEGMAFIA', 'url': 'https://www.last.fm/tag/JPEGMAFIA'}, {'count': 3, 'name': 'noise', 'url': 'https://www.last.fm/tag/noise'}, {'count': 3, 'name': 'pop', 'url': 'https://www.last.fm/tag/pop'}, {'count': 3, 'name': 'punk', 'url': 'https://www.last.fm/tag/punk'}, {'count': 3, 'name': 'alternative', 'url': 'https://www.last.fm/tag/alternative'}, {'count': 3, 'name': 'new york', 'url': 'https://www.last.fm/tag/new+york'}, {'count': 3, 'name': 'Lo-Fi', 'url': 'https://www.last.fm/tag/Lo-Fi'}, {'count': 3, 'name': 'avant garde', 'url': 'https://www.last.fm/tag/avant+garde'}, {'count': 3, 'name': 'Brooklyn', 'url': 'https://www.last.fm/tag/Brooklyn'}, {'count': 3, 'name': 'Avant-Garde', 'url': 'https://www.last.fm/tag/Avant-Garde'}, {'count': 3, 'name': 'atmospheric drum and bass', 'url': 'https://ww ...
# {'toptags': {'tag': [], '@attr': {'artist': 'Alexandra Irwin'}}}
# Error or no tags found for artist: Alexandra Irwin
# {'toptags': {'tag': [{'count': 100, 'name': 'Hip-Hop', 'url': 'https://www.last.fm/tag/Hip-Hop'}, {'count': 100, 'name': 'jazz', 'url': 'https://www.last.fm/tag/jazz'}, {'count': 100, 'name': 'pop', 'url': 'https://www.last.fm/tag/pop'}, {'count': 100, 'name': 'soul', 'url': 'https://www.last.fm/tag/soul'}, {'count': 100, 'name': 'reggae', 'url': 'https://www.last.fm/tag/reggae'}, {'count': 100, 'name': 'rap', 'url': 'https://www.last.fm/tag/rap'}, {'count': 100, 'name': 'female vocalists', 'url': 'https://www.last.fm/tag/female+vocalists'}, {'count': 100, 'name': 'USA', 'url': 'https://www.last.fm/tag/USA'}, {'count': 100, 'name': 'dance', 'url': 'https://www.last.fm/tag/dance'}, {'count': 100, 'name': '90s', 'url': 'https://www.last.fm/tag/90s'}, {'count': 100, 'name': 'breakbeat', 'url': 'https://www.last.fm/tag/breakbeat'}, {'count': 100, 'name': 'musical', 'url': 'https://www.last.fm/tag/musical'}, {'count': 100, 'name': 'rnb', 'url': 'https://www.last.fm/tag/rnb'}, {'count': 100, 'name': 'eurodance', 'url': 'https://www.last.fm/tag/eurodance'}, {'count': 100, 'name': 'Houston', 'url': 'https://www.last.fm/tag/Houston'}, {'count': 100, 'name': 'multiple artists', 'url': 'https://www.last.fm/tag/multiple+artists'}, {'count': 100, 'name': 'Breaks Breakbeat RSOF', 'url': 'https://www.last.fm/tag/Breaks+Breakbeat+RSOF'}, {'count': 100, 'name': ' US', 'url': 'https://www.last.fm/tag/+US'}], '@attr': {'artist': 'Reggie'}}}
# {'toptags': {'tag': [{'count': 100, 'name': 'krautrock', 'url': 'https://www.last.fm/tag/krautrock'}, {'count': 60, 'name': 'experimental', 'url': 'https://www.last.fm/tag/experimental'}, {'count': 52, 'name': 'psychedelic', 'url': 'https://www.last.fm/tag/psychedelic'}, {'count': 48, 'name': 'Progressive rock', 'url': 'https://www.last.fm/tag/Progressive+rock'}, {'count': 26, 'name': 'german', 'url': 'https://www.last.fm/tag/german'}, {'count': 16, 'name': 'Psychedelic Rock', 'url': 'https://www.last.fm/tag/Psychedelic+Rock'}, {'count': 13, 'name': 'Avant-Garde', 'url': 'https://www.last.fm/tag/Avant-Garde'}, {'count': 11, 'name': 'rock', 'url': 'https://www.last.fm/tag/rock'}, {'count': 9, 'name': 'Experimental Rock', 'url': 'https://www.last.fm/tag/Experimental+Rock'}, {'count': 7, 'name': 'electronic', 'url': 'https://www.last.fm/tag/electronic'}, {'count': 6, 'name': '70s', 'url': 'https://www.last.fm/tag/70s'}, {'count': 5, 'name': 'Progressive', 'url': 'https://www.last.fm/tag/Progressive'}, {'count': 4, 'name': 'germany', 'url': 'https://www.last.fm/tag/germany'}, {'count': 3, 'name': 'art rock', 'url': 'https://www.last.fm/tag/art+rock'}, {'count': 3, 'name': 'Kraut Rock', 'url': 'https://www.last.fm/tag/Kraut+Rock'}, {'count': 3, 'name': 'ambient', 'url': 'https://www.last.fm/tag/ambient'}, {'count': 3, 'name': 'can', 'url': 'https://www.last.fm/tag/can'}, {'count': 2, 'name': 'classic rock', 'url': 'https://www.last.fm/tag/classic+rock'}, {'count': 2, 'name': 'space rock', 'url': 'https://www.last.fm/tag/space+rock'}, {'count': 2, 'name': 'indie', 'url': 'https://www.last.fm/tag/indie'}, {'count': 2, 'name': 'alternative', 'url': 'https://www.last.fm/tag/alternative'}, {'count': 2, 'name': 'prog', 'url': 'https://www.last.fm/tag/prog'}, {'count': 2, 'name': '60s', 'url': 'https://www.last.fm/tag/60s'}, {'count': 2, 'name': 'kraut', 'url': 'https://www.last.fm/tag/kraut'}, {'count': 2, 'name': 'Cologne', 'url': 'https://www.last.fm/tag/Cologne'}, {'count': 2, 'name': 'noise', 'url': 'https://www.last.fm/tag/noise'}, {'count': 2, 'name': 'avantgarde', 'url': 'https://www.last.fm/tag/avantgarde'}, {'count': 2, 'name': 'proto-punk', 'url': 'https://www.last.fm/tag/proto-punk'}, {'count': 1, 'name': 'funk', 'url': 'https://www.last.fm/tag/funk'}, {'count': 1, 'name': 'electronica', 'url': 'https://www.last.fm/tag/electronica'}, {'count': 1, 'name': 'jazz', 'url': 'https://www.last.fm/tag/jazz'}, {'count': 1, 'name': 'deutsch', 'url': 'https://www.last.fm/tag/deutsch'}], '@attr': {'artist': 'Can'}}}
# {'toptags': {'tag': [{'count': 100, 'name': 'rap', 'url': 'https://www.last.fm/tag/rap'}, {'count': 87, 'name': 'Hip-Hop', 'url': 'https://www.last.fm/tag/Hip-Hop'}, {'count': 67, 'name': 'hip hop', 'url': 'https://www.last.fm/tag/hip+hop'}, {'count': 60, 'name': 'boom bap', 'url': 'https://www.last.fm/tag/boom+bap'}, {'count': 54, 'name': 'Gangsta Rap', 'url': 'https://www.last.fm/tag/Gangsta+Rap'}, {'count': 54, 'name': 'hardcore hip hop', 'url': 'https://www.last.fm/tag/hardcore+hip+hop'}, {'count': 47, 'name': 'new york', 'url': 'https://www.last.fm/tag/new+york'}, {'count': 40, 'name': 'east coast hip hop', 'url': 'https://www.last.fm/tag/east+coast+hip+hop'}, {'count': 34, 'name': 'Buffalo', 'url': 'https://www.last.fm/tag/Buffalo'}, {'count': 34, 'name': 'drumless', 'url': 'https://www.last.fm/tag/drumless'}, {'count': 27, 'name': 'griselda', 'url': 'https://www.last.fm/tag/griselda'}, {'count': 20, 'name': 'trap', 'url': 'https://www.last.fm/tag/trap'}, {'count': 20, 'name': 'east coast hip-hop', 'url': 'https://www.last.fm/tag/east+coast+hip-hop'}, {'count': 14, 'name': 'underground hip-hop', 'url': 'https://www.last.fm/tag/underground+hip-hop'}, {'count': 14, 'name': 'hardcore hip-hop', 'url': 'https://www.last.fm/tag/hardcore+hip-hop'}, {'count': 14, 'name': 'east coast rap', 'url': 'https://www.last.fm/tag/east+coast+rap'}, {'count': 14, 'name': 'United States', 'url': 'https://www.last.fm/tag/United+States'}, {'count': 7, 'name': 'seen live', 'url': 'https://www.last.fm/tag/seen+live'}, {'count': 7, 'name': 'american', 'url': 'https://www.last.fm/tag/american'}, {'count': 7, 'name': 'hiphop', 'url': 'https://www.last.fm/tag/hiphop'}, {'count': 7, 'name': 'hardcore rap', 'url': 'https://www.last.fm/tag/hardcore+rap'}, {'count': 7, 'name': 'ny', 'url': 'https://www.last.fm/tag/ny'}, {'count': 7, 'name': 'jazz rap', 'url': 'https://www.last.fm/tag/jazz+rap'}, {'count': 7, 'name': 'Coke Rap', 'url': 'https://www.last.fm/tag/Coke+Rap'}, {'count': 7, 'name': 'jazz hip-hop', 'url': 'https://www.last.fm/tag/jazz+hip-hop'}, {'count': 7, 'name': 'western new york', 'url': 'https://www.last.fm/tag/western+new+york'}, {'count': 7, 'name': 'western ny', 'url': 'https://www.last.fm/tag/western+ny'}, {'count': 7, 'name': 'WNY', 'url': 'https://www.last.fm/tag/WNY'}, {'count': 7, 'name': 'undergroundrap', 'url': 'https://www.last.fm/tag/undergroundrap'}, {'count': 7, 'name': 'GxFR', 'url': 'https://www.last.fm/tag/GxFR'}, {'count': 7, 'name': 'Westside Gunn', 'url': 'https://www.last.fm/tag/Westside+Gunn'}], '@attr': {'artist': 'Westside Gunn'}}}
# {'toptags': {'tag': [{'count': 100, 'name': 'eurodance', 'url': 'https://www.last.fm/tag/eurodance'}, {'count': 85, 'name': 'dance', 'url': 'https://www.last.fm/tag/dance'}, {'count': 70, 'name': '90s', 'url': 'https://www.last.fm/tag/90s'}, {'count': 42, 'name': 'pop', 'url': 'https://www.last.fm/tag/pop'}, {'count': 29, 'name': 'female vocalists', 'url': 'https://www.last.fm/tag/female+vocalists'}, {'count': 17, 'name': 'german', 'url': 'https://www.last.fm/tag/german'}, {'count': 12, 'name': 'electronic', 'url': 'https://www.last.fm/tag/electronic'}, {'count': 10, 'name': 'House', 'url': 'https://www.last.fm/tag/House'}, {'count': 8, 'name': 'Disco', 'url': 'https://www.last.fm/tag/Disco'}, {'count': 7, 'name': '90s dance', 'url': 'https://www.last.fm/tag/90s+dance'}, {'count': 5, 'name': 'electronica', 'url': 'https://www.last.fm/tag/electronica'}, {'count': 5, 'name': 'germany', 'url': 'https://www.last.fm/tag/germany'}, {'count': 4, 'name': 'techno', 'url': 'https://www.last.fm/tag/techno'}, {'count': 4, 'name': 'La Bouche', 'url': 'https://www.last.fm/tag/La+Bouche'}, {'count': 3, 'name': 'club', 'url': 'https://www.last.fm/tag/club'}, {'count': 3, 'name': 'eurobeat', 'url': 'https://www.last.fm/tag/eurobeat'}, {'count': 3, 'name': 'female vocalist', 'url': 'https://www.last.fm/tag/female+vocalist'}, {'count': 3, 'name': 'Hi-NRG', 'url': 'https://www.last.fm/tag/Hi-NRG'}, {'count': 2, 'name': 'Hip-Hop', 'url': 'https://www.last.fm/tag/Hip-Hop'}, {'count': 2, 'name': "90's", 'url': 'https://www.last.fm/tag/90%27s'}, {'count': 2, 'name': 'trance', 'url': 'https://www.last.fm/tag/trance'}, {'count': 2, 'name': 'female', 'url': 'https://www.last.fm/tag/female'}, {'count': 2, 'name': 'rock', 'url': 'https://www.last.fm/tag/rock'}, {'count': 2, 'name': 'Dead', 'url': 'https://www.last.fm/tag/Dead'}, {'count': 2, 'name': 'dance-pop', 'url': 'https://www.last.fm/tag/dance-pop'}, {'count': 2, 'name': 'Retro', 'url': 'https://www.last.fm/tag/Retro'}, {'count': 2, 'name': 'Europop', 'url': 'https://www.last.fm/tag/Europop'}, {'count': 2, 'name': 'instrumental', 'url': 'https://www.last.fm/tag/instrumental'}, {'count': 2, 'name': 'alternative', 'url': 'https://www.last.fm/tag/alternative'}, {'count': 2, 'name': 'rap', 'url': 'https://www.last.fm/tag/rap'}, {'count': 2, 'name': '00s', 'url': 'https://www.last.fm/tag/00s'}, {'count': 2, 'name': 'european', 'url': 'https://www.last.fm/tag/european'}, {'count': 2, 'name': 'la  bouche', 'url': 'https://www.last.fm/tag/la++bouche'}], '@attr': {'artist': 'La Bouche'}}}
# {'toptags': {'tag': [{'count': 100, 'name': 'k-pop', 'url': 'https://www.last.fm/tag/k-pop'}, {'count': 85, 'name': 'j-pop', 'url': 'https://www.last.fm/tag/j-pop'}, {'count': 70, 'name': 'pop', 'url': 'https://www.last.fm/tag/pop'}, {'count': 70, 'name': 'japanese', 'url': 'https://www.last.fm/tag/japanese'}, {'count': 62, 'name': 'rnb', 'url': 'https://www.last.fm/tag/rnb'}, {'count': 54, 'name': 'Korean', 'url': 'https://www.last.fm/tag/Korean'}, {'count': 47, 'name': 'love live', 'url': 'https://www.last.fm/tag/love+live'}, {'count': 39, 'name': 'k-rnb', 'url': 'https://www.last.fm/tag/k-rnb'}, {'count': 31, 'name': 'rap', 'url': 'https://www.last.fm/tag/rap'}, {'count': 31, 'name': 'female vocalists', 'url': 'https://www.last.fm/tag/female+vocalists'}, {'count': 31, 'name': 'House', 'url': 'https://www.last.fm/tag/House'}, {'count': 31, 'name': 'remix', 'url': 'https://www.last.fm/tag/remix'}, {'count': 31, 'name': 'Kpop', 'url': 'https://www.last.fm/tag/Kpop'}, {'count': 24, 'name': 'Hip-Hop', 'url': 'https://www.last.fm/tag/Hip-Hop'}, {'count': 24, 'name': 'anime', 'url': 'https://www.last.fm/tag/anime'}, {'count': 24, 'name': 'idol', 'url': 'https://www.last.fm/tag/idol'}, {'count': 24, 'name': 'khh', 'url': 'https://www.last.fm/tag/khh'}, {'count': 16, 'name': 'seen live', 'url': 'https://www.last.fm/tag/seen+live'}, {'count': 16, 'name': 'soul', 'url': 'https://www.last.fm/tag/soul'}, {'count': 16, 'name': 'JPop', 'url': 'https://www.last.fm/tag/JPop'}, {'count': 16, 'name': 'Korea', 'url': 'https://www.last.fm/tag/Korea'}, {'count': 16, 'name': 'Romanian Pop', 'url': 'https://www.last.fm/tag/Romanian+Pop'}, {'count': 16, 'name': 'krnb', 'url': 'https://www.last.fm/tag/krnb'}, {'count': 16, 'name': 'BiBi', 'url': 'https://www.last.fm/tag/BiBi'}, {'count': 16, 'name': 'LoveLive', 'url': 'https://www.last.fm/tag/LoveLive'}, {'count': 8, 'name': 'electronic', 'url': 'https://www.last.fm/tag/electronic'}, {'count': 8, 'name': 'electropop', 'url': 'https://www.last.fm/tag/electropop'}, {'count': 8, 'name': 'indie', 'url': 'https://www.last.fm/tag/indie'}, {'count': 8, 'name': 'experimental', 'url': 'https://www.last.fm/tag/experimental'}, {'count': 8, 'name': '3', 'url': 'https://www.last.fm/tag/3'}, {'count': 8, 'name': 'hiphop', 'url': 'https://www.last.fm/tag/hiphop'}, {'count': 8, 'name': 'ost', 'url': 'https://www.last.fm/tag/ost'}, {'count': 8, 'name': '1998', 'url': 'https://www.last.fm/tag/1998'}, {'count': 8, 'name': 'Asian', 'url': 'https://www.last.fm/tag/Asian'}, {'count': 8, 'name': 'game', 'url': 'https://www.last.fm/tag/game'}, {'count': 8, 'name': 'rhythm and blues', 'url': 'https://www.last.fm/tag/rhythm+and+blues'}, {'count': 8, 'name': 'producer', 'url': 'https://www.last.fm/tag/producer'}, {'count': 8, 'name': 'Romanian', 'url': 'https://www.last.fm/tag/Romanian'}, {'count': 8, 'name': 'female singer', 'url': 'https://www.last.fm/tag/female+singer'}, {'count': 8, 'name': 'trap', 'url': 'https://www.last.fm/tag/trap'}, {'count': 8, 'name': 'eurobeat', 'url': 'https://www.last.fm/tag/eurobeat'}, {'count': 8, 'name': 'Black Rock', 'url': 'https://www.last.fm/tag/Black+Rock'}, {'count': 8, 'name': 'latin house', 'url': 'https://www.last.fm/tag/latin+house'}, {'count': 8, 'name': 'Rapper', 'url': 'https://www.last.fm/tag/Rapper'}, {'count': 8, 'name': 'contemporary rnb', 'url': 'https://www.last.fm/tag/contemporary+rnb'}, {'count': 8, 'name': 'asian music', 'url': 'https://www.last.fm/tag/asian+music'}, {'count': 8, 'name': 'south korean', 'url': 'https://www.last.fm/tag/south+korean'}, {'count': 8, 'name': 'alternative rnb', 'url': 'https://www.last.fm/tag/alternative+rnb'}, {'count': 8, 'name': 'k-indie', 'url': 'https://www.last.fm/tag/k-indie'}, {'count': 8, 'name': 'Asian Pop', 'url': 'https://www.last.fm/tag/Asian+Pop'}, {'count': 8, 'name': 'Korean Hip Hop', 'url': 'https://www.last.fm/tag/Korean+Hip+Hop'}, {'count': 8, 'name': 'not jpop', 'url': 'https://www.last.fm/tag/not+jpop'}, {'count': 8, 'nam ...
# {'toptags': {'tag': [{'count': 100, 'name': 'dream pop', 'url': 'https://www.last.fm/tag/dream+pop'}, {'count': 74, 'name': 'shoegaze', 'url': 'https://www.last.fm/tag/shoegaze'}, {'count': 54, 'name': 'indie pop', 'url': 'https://www.last.fm/tag/indie+pop'}, {'count': 54, 'name': 'Lo-Fi', 'url': 'https://www.last.fm/tag/Lo-Fi'}, {'count': 47, 'name': 'seen live', 'url': 'https://www.last.fm/tag/seen+live'}, {'count': 47, 'name': 'indie rock', 'url': 'https://www.last.fm/tag/indie+rock'}, {'count': 27, 'name': 'indie', 'url': 'https://www.last.fm/tag/indie'}, {'count': 27, 'name': 'bedroom pop', 'url': 'https://www.last.fm/tag/bedroom+pop'}, {'count': 20, 'name': 'female vocalists', 'url': 'https://www.last.fm/tag/female+vocalists'}, {'count': 20, 'name': 'american', 'url': 'https://www.last.fm/tag/american'}, {'count': 14, 'name': 'rock', 'url': 'https://www.last.fm/tag/rock'}, {'count': 14, 'name': 'Lo-Fi Indie', 'url': 'https://www.last.fm/tag/Lo-Fi+Indie'}, {'count': 7, 'name': 'pop', 'url': 'https://www.last.fm/tag/pop'}, {'count': 7, 'name': 'Grunge', 'url': 'https://www.last.fm/tag/Grunge'}, {'count': 7, 'name': 'alternative', 'url': 'https://www.last.fm/tag/alternative'}, {'count': 7, 'name': 'alternative rock', 'url': 'https://www.last.fm/tag/alternative+rock'}, {'count': 7, 'name': 'noise rock', 'url': 'https://www.last.fm/tag/noise+rock'}, {'count': 7, 'name': 'pop rock', 'url': 'https://www.last.fm/tag/pop+rock'}, {'count': 7, 'name': 'americana', 'url': 'https://www.last.fm/tag/americana'}, {'count': 7, 'name': 'noise pop', 'url': 'https://www.last.fm/tag/noise+pop'}, {'count': 7, 'name': 'Alt-country', 'url': 'https://www.last.fm/tag/Alt-country'}, {'count': 7, 'name': 'slowcore', 'url': 'https://www.last.fm/tag/slowcore'}, {'count': 7, 'name': 'garage', 'url': 'https://www.last.fm/tag/garage'}, {'count': 7, 'name': 'indie folk', 'url': 'https://www.last.fm/tag/indie+folk'}, {'count': 7, 'name': 'male vocalists', 'url': 'https://www.last.fm/tag/male+vocalists'}, {'count': 7, 'name': 'female vocalist', 'url': 'https://www.last.fm/tag/female+vocalist'}, {'count': 7, 'name': 'alternative country', 'url': 'https://www.last.fm/tag/alternative+country'}, {'count': 7, 'name': 'surf rock', 'url': 'https://www.last.fm/tag/surf+rock'}, {'count': 7, 'name': 'female vocal', 'url': 'https://www.last.fm/tag/female+vocal'}, {'count': 7, 'name': 'diy', 'url': 'https://www.last.fm/tag/diy'}, {'count': 7, 'name': '4', 'url': 'https://www.last.fm/tag/4'}, {'count': 7, 'name': '2010s', 'url': 'https://www.last.fm/tag/2010s'}, {'count': 7, 'name': '20s', 'url': 'https://www.last.fm/tag/20s'}, {'count': 7, 'name': 'wisconsin', 'url': 'https://www.last.fm/tag/wisconsin'}, {'count': 7, 'name': 'madison', 'url': 'https://www.last.fm/tag/madison'}, {'count': 7, 'name': 'surf pop', 'url': 'https://www.last.fm/tag/surf+pop'}, {'count': 7, 'name': 'slacker rock', 'url': 'https://www.last.fm/tag/slacker+rock'}, {'count': 7, 'name': 'lo-fi rock', 'url': 'https://www.last.fm/tag/lo-fi+rock'}, {'count': 7, 'name': 'Grunge Pop', 'url': 'https://www.last.fm/tag/Grunge+Pop'}, {'count': 7, 'name': 'dream punk', 'url': 'https://www.last.fm/tag/dream+punk'}, {'count': 7, 'name': '2020s', 'url': 'https://www.last.fm/tag/2020s'}, {'count': 7, 'name': 'ten million plays', 'url': 'https://www.last.fm/tag/ten+million+plays'}, {'count': 7, 'name': 'yandex music', 'url': 'https://www.last.fm/tag/yandex+music'}, {'count': 7, 'name': '0323', 'url': 'https://www.last.fm/tag/0323'}], '@attr': {'artist': 'Slow Pulp'}}}
# {'toptags': {'tag': [{'count': 100, 'name': 'House', 'url': 'https://www.last.fm/tag/House'}, {'count': 58, 'name': 'deep house', 'url': 'https://www.last.fm/tag/deep+house'}, {'count': 43, 'name': 'electronic', 'url': 'https://www.last.fm/tag/electronic'}, {'count': 43, 'name': 'techno', 'url': 'https://www.last.fm/tag/techno'}, {'count': 29, 'name': 'breaks', 'url': 'https://www.last.fm/tag/breaks'}, {'count': 15, 'name': 'seen live', 'url': 'https://www.last.fm/tag/seen+live'}, {'count': 15, 'name': 'detroit techno', 'url': 'https://www.last.fm/tag/detroit+techno'}, {'count': 15, 'name': 'ireland', 'url': 'https://www.last.fm/tag/ireland'}, {'count': 15, 'name': 'detroit electro', 'url': 'https://www.last.fm/tag/detroit+electro'}], '@attr': {'artist': 'Kettama'}}}
# {'toptags': {'tag': [{'count': 100, 'name': 'electronic', 'url': 'https://www.last.fm/tag/electronic'}, {'count': 100, 'name': 'experimental', 'url': 'https://www.last.fm/tag/experimental'}, {'count': 94, 'name': 'idm', 'url': 'https://www.last.fm/tag/idm'}, {'count': 73, 'name': 'Drum and bass', 'url': 'https://www.last.fm/tag/Drum+and+bass'}, {'count': 49, 'name': 'Progressive rock', 'url': 'https://www.last.fm/tag/Progressive+rock'}, {'count': 28, 'name': 'Power metal', 'url': 'https://www.last.fm/tag/Power+metal'}, {'count': 25, 'name': 'jungle', 'url': 'https://www.last.fm/tag/jungle'}, {'count': 22, 'name': 'rock', 'url': 'https://www.last.fm/tag/rock'}, {'count': 22, 'name': 'glitch', 'url': 'https://www.last.fm/tag/glitch'}, {'count': 16, 'name': 'electronica', 'url': 'https://www.last.fm/tag/electronica'}, {'count': 16, 'name': 'UK', 'url': 'https://www.last.fm/tag/UK'}, {'count': 16, 'name': 'Drum n Bass', 'url': 'https://www.last.fm/tag/Drum+n+Bass'}, {'count': 13, 'name': 'metal', 'url': 'https://www.last.fm/tag/metal'}, {'count': 13, 'name': 'hardcore', 'url': 'https://www.last.fm/tag/hardcore'}, {'count': 13, 'name': 'screamo', 'url': 'https://www.last.fm/tag/screamo'}, {'count': 13, 'name': 'dnb', 'url': 'https://www.last.fm/tag/dnb'}, {'count': 13, 'name': 'melodic hardcore', 'url': 'https://www.last.fm/tag/melodic+hardcore'}, {'count': 10, 'name': 'heavy metal', 'url': 'https://www.last.fm/tag/heavy+metal'}, {'count': 10, 'name': 'seen live', 'url': 'https://www.last.fm/tag/seen+live'}, {'count': 10, 'name': 'techno', 'url': 'https://www.last.fm/tag/techno'}, {'count': 10, 'name': 'drumfunk', 'url': 'https://www.last.fm/tag/drumfunk'}, {'count': 10, 'name': 'post-hardcore', 'url': 'https://www.last.fm/tag/post-hardcore'}, {'count': 7, 'name': 'trance', 'url': 'https://www.last.fm/tag/trance'}, {'count': 7, 'name': 'indie', 'url': 'https://www.last.fm/tag/indie'}, {'count': 7, 'name': 'british', 'url': 'https://www.last.fm/tag/british'}, {'count': 7, 'name': 'reggae', 'url': 'https://www.last.fm/tag/reggae'}, {'count': 7, 'name': 'ambient', 'url': 'https://www.last.fm/tag/ambient'}, {'count': 7, 'name': 'hard rock', 'url': 'https://www.last.fm/tag/hard+rock'}, {'count': 7, 'name': 'abstract', 'url': 'https://www.last.fm/tag/abstract'}, {'count': 7, 'name': 'atmospheric drum and bass', 'url': 'https://www.last.fm/tag/atmospheric+drum+and+bass'}, {'count': 7, 'name': 'Psychedelic Rock', 'url': 'https://www.last.fm/tag/Psychedelic+Rock'}, {'count': 7, 'name': 'Jazz Rock', 'url': 'https://www.last.fm/tag/Jazz+Rock'}, {'count': 7, 'name': 'roots reggae', 'url': 'https://www.last.fm/tag/roots+reggae'}, {'count': 7, 'name': 'PostEverything', 'url': 'https://www.last.fm/tag/PostEverything'}, {'count': 7, 'name': 'heavy psych', 'url': 'https://www.last.fm/tag/heavy+psych'}, {'count': 7, 'name': 'All', 'url': 'https://www.last.fm/tag/All'}, {'count': 7, 'name': 'post jungle', 'url': 'https://www.last.fm/tag/post+jungle'}, {'count': 4, 'name': 'classic rock', 'url': 'https://www.last.fm/tag/classic+rock'}, {'count': 4, 'name': 'metalcore', 'url': 'https://www.last.fm/tag/metalcore'}, {'count': 4, 'name': 'Hip-Hop', 'url': 'https://www.last.fm/tag/Hip-Hop'}, {'count': 4, 'name': 'pop', 'url': 'https://www.last.fm/tag/pop'}, {'count': 4, 'name': '70s', 'url': 'https://www.last.fm/tag/70s'}, {'count': 4, 'name': 'punk', 'url': 'https://www.last.fm/tag/punk'}, {'count': 4, 'name': 'alternative', 'url': 'https://www.last.fm/tag/alternative'}, {'count': 4, 'name': 'rap', 'url': 'https://www.last.fm/tag/rap'}, {'count': 4, 'name': 'Progressive metal', 'url': 'https://www.last.fm/tag/Progressive+metal'}, {'count': 4, 'name': 'dance', 'url': 'https://www.last.fm/tag/dance'}, {'count': 4, 'name': 'Stoner Rock', 'url': 'https://www.last.fm/tag/Stoner+Rock'}, {'count': 4, 'name': 'Fusion', 'url': 'https://www.last.fm/tag/Fusion'}, {'count': 4, 'name': 'Gothic', 'url': 'https://www.last.fm/tag/Gothic'}, {'count': 4, 'name': 'indietron ...
# {'toptags': {'tag': [{'count': 100, 'name': 'australian', 'url': 'https://www.last.fm/tag/australian'}, {'count': 78, 'name': 'indie', 'url': 'https://www.last.fm/tag/indie'}, {'count': 56, 'name': 'folk', 'url': 'https://www.last.fm/tag/folk'}, {'count': 56, 'name': 'indie folk', 'url': 'https://www.last.fm/tag/indie+folk'}, {'count': 45, 'name': 'seen live', 'url': 'https://www.last.fm/tag/seen+live'}, {'count': 45, 'name': 'australia', 'url': 'https://www.last.fm/tag/australia'}, {'count': 34, 'name': 'alternative', 'url': 'https://www.last.fm/tag/alternative'}, {'count': 23, 'name': 'indie rock', 'url': 'https://www.last.fm/tag/indie+rock'}, {'count': 12, 'name': 'rock', 'url': 'https://www.last.fm/tag/rock'}, {'count': 12, 'name': 'soul', 'url': 'https://www.last.fm/tag/soul'}, {'count': 12, 'name': 'alternative rock', 'url': 'https://www.last.fm/tag/alternative+rock'}, {'count': 12, 'name': 'indie pop', 'url': 'https://www.last.fm/tag/indie+pop'}, {'count': 12, 'name': 'twee', 'url': 'https://www.last.fm/tag/twee'}, {'count': 12, 'name': 'psychedelic pop', 'url': 'https://www.last.fm/tag/psychedelic+pop'}, {'count': 12, 'name': 'psychedelic', 'url': 'https://www.last.fm/tag/psychedelic'}, {'count': 12, 'name': '10s', 'url': 'https://www.last.fm/tag/10s'}, {'count': 12, 'name': 'neo-psychedelic', 'url': 'https://www.last.fm/tag/neo-psychedelic'}, {'count': 12, 'name': 'food and drink', 'url': 'https://www.last.fm/tag/food+and+drink'}, {'count': 12, 'name': 'hairy chest', 'url': 'https://www.last.fm/tag/hairy+chest'}, {'count': 12, 'name': 'hunks', 'url': 'https://www.last.fm/tag/hunks'}, {'count': 12, 'name': 'fruit and vegetables', 'url': 'https://www.last.fm/tag/fruit+and+vegetables'}, {'count': 12, 'name': 'Angus Stone', 'url': 'https://www.last.fm/tag/Angus+Stone'}, {'count': 12, 'name': 'nice fur', 'url': 'https://www.last.fm/tag/nice+fur'}, {'count': 12, 'name': 'heavy pelt', 'url': 'https://www.last.fm/tag/heavy+pelt'}], '@attr': {'artist': 'Dope Lemon'}}}
# {'toptags': {'tag': [{'count': 100, 'name': 'rnb', 'url': 'https://www.last.fm/tag/rnb'}, {'count': 82, 'name': 'electronic', 'url': 'https://www.last.fm/tag/electronic'}, {'count': 73, 'name': 'pop', 'url': 'https://www.last.fm/tag/pop'}, {'count': 64, 'name': 'seen live', 'url': 'https://www.last.fm/tag/seen+live'}, {'count': 64, 'name': 'british', 'url': 'https://www.last.fm/tag/british'}, {'count': 64, 'name': 'UK Garage', 'url': 'https://www.last.fm/tag/UK+Garage'}, {'count': 64, 'name': 'bedroom pop', 'url': 'https://www.last.fm/tag/bedroom+pop'}, {'count': 64, 'name': '2-step', 'url': 'https://www.last.fm/tag/2-step'}, {'count': 55, 'name': 'Drum and bass', 'url': 'https://www.last.fm/tag/Drum+and+bass'}, {'count': 46, 'name': 'female vocalists', 'url': 'https://www.last.fm/tag/female+vocalists'}, {'count': 46, 'name': 'atmospheric drum and bass', 'url': 'https://www.last.fm/tag/atmospheric+drum+and+bass'}, {'count': 46, 'name': 'dnb', 'url': 'https://www.last.fm/tag/dnb'}, {'count': 37, 'name': 'dance-pop', 'url': 'https://www.last.fm/tag/dance-pop'}, {'count': 37, 'name': 'jungle', 'url': 'https://www.last.fm/tag/jungle'}, {'count': 28, 'name': 'alt-pop', 'url': 'https://www.last.fm/tag/alt-pop'}, {'count': 28, 'name': 'hyperpop', 'url': 'https://www.last.fm/tag/hyperpop'}, {'count': 19, 'name': 'indie pop', 'url': 'https://www.last.fm/tag/indie+pop'}, {'count': 19, 'name': 'dance', 'url': 'https://www.last.fm/tag/dance'}, {'count': 19, 'name': 'Queen', 'url': 'https://www.last.fm/tag/Queen'}, {'count': 19, 'name': 'Lo-Fi', 'url': 'https://www.last.fm/tag/Lo-Fi'}, {'count': 19, 'name': 'Drum n Bass', 'url': 'https://www.last.fm/tag/Drum+n+Bass'}, {'count': 19, 'name': 'United Kingdom', 'url': 'https://www.last.fm/tag/United+Kingdom'}, {'count': 19, 'name': 'contemporary rnb', 'url': 'https://www.last.fm/tag/contemporary+rnb'}, {'count': 19, 'name': 'alternative rnb', 'url': 'https://www.last.fm/tag/alternative+rnb'}, {'count': 19, 'name': '2020s', 'url': 'https://www.last.fm/tag/2020s'}, {'count': 19, 'name': 'pinkpantheress', 'url': 'https://www.last.fm/tag/pinkpantheress'}, {'count': 10, 'name': 'trip-hop', 'url': 'https://www.last.fm/tag/trip-hop'}, {'count': 10, 'name': 'electropop', 'url': 'https://www.last.fm/tag/electropop'}, {'count': 10, 'name': 'indie', 'url': 'https://www.last.fm/tag/indie'}, {'count': 10, 'name': 'indie electronic', 'url': 'https://www.last.fm/tag/indie+electronic'}, {'count': 10, 'name': 'UK', 'url': 'https://www.last.fm/tag/UK'}, {'count': 10, 'name': 'Druggy', 'url': 'https://www.last.fm/tag/Druggy'}, {'count': 10, 'name': 'romantic', 'url': 'https://www.last.fm/tag/romantic'}, {'count': 10, 'name': 'House', 'url': 'https://www.last.fm/tag/House'}, {'count': 10, 'name': 'melodic', 'url': 'https://www.last.fm/tag/melodic'}, {'count': 10, 'name': 'Dreamy', 'url': 'https://www.last.fm/tag/Dreamy'}, {'count': 10, 'name': 'quirky', 'url': 'https://www.last.fm/tag/quirky'}, {'count': 10, 'name': 'relaxed', 'url': 'https://www.last.fm/tag/relaxed'}, {'count': 10, 'name': 'thoughtful', 'url': 'https://www.last.fm/tag/thoughtful'}, {'count': 10, 'name': 'england', 'url': 'https://www.last.fm/tag/england'}, {'count': 10, 'name': 'Reflective', 'url': 'https://www.last.fm/tag/Reflective'}, {'count': 10, 'name': 'atmospheric', 'url': 'https://www.last.fm/tag/atmospheric'}, {'count': 10, 'name': 'spacious', 'url': 'https://www.last.fm/tag/spacious'}, {'count': 10, 'name': 'breakbeat', 'url': 'https://www.last.fm/tag/breakbeat'}, {'count': 10, 'name': 'Passionate', 'url': 'https://www.last.fm/tag/Passionate'}, {'count': 10, 'name': 'introspective', 'url': 'https://www.last.fm/tag/introspective'}, {'count': 10, 'name': 'melancholy', 'url': 'https://www.last.fm/tag/melancholy'}, {'count': 10, 'name': 'gentle', 'url': 'https://www.last.fm/tag/gentle'}, {'count': 10, 'name': 'ethereal', 'url': 'https://www.last.fm/tag/ethereal'}, {'count': 10, 'name': 'Rainy Day', 'url': 'https://www.last.fm/tag/Rainy+Day ...
# {'toptags': {'tag': [{'count': 100, 'name': 'a cappella', 'url': 'https://www.last.fm/tag/a+cappella'}, {'count': 69, 'name': '80s', 'url': 'https://www.last.fm/tag/80s'}, {'count': 62, 'name': 'pop', 'url': 'https://www.last.fm/tag/pop'}, {'count': 50, 'name': 'british', 'url': 'https://www.last.fm/tag/british'}, {'count': 29, 'name': 'a capella', 'url': 'https://www.last.fm/tag/a+capella'}, {'count': 13, 'name': 'Acapella', 'url': 'https://www.last.fm/tag/Acapella'}, {'count': 9, 'name': 'male vocalists', 'url': 'https://www.last.fm/tag/male+vocalists'}, {'count': 9, 'name': 'acappela', 'url': 'https://www.last.fm/tag/acappela'}, {'count': 8, 'name': 'seen live', 'url': 'https://www.last.fm/tag/seen+live'}, {'count': 8, 'name': 'cover', 'url': 'https://www.last.fm/tag/cover'}, {'count': 8, 'name': 'one hit wonder', 'url': 'https://www.last.fm/tag/one+hit+wonder'}, {'count': 6, 'name': 'UK', 'url': 'https://www.last.fm/tag/UK'}, {'count': 6, 'name': '1980s', 'url': 'https://www.last.fm/tag/1980s'}, {'count': 6, 'name': '7 stars', 'url': 'https://www.last.fm/tag/7+stars'}, {'count': 6, 'name': 'a-cappella', 'url': 'https://www.last.fm/tag/a-cappella'}, {'count': 4, 'name': 'english', 'url': 'https://www.last.fm/tag/english'}, {'count': 4, 'name': 'male vocals', 'url': 'https://www.last.fm/tag/male+vocals'}, {'count': 4, 'name': 'zagraniczne', 'url': 'https://www.last.fm/tag/zagraniczne'}, {'count': 2, 'name': 'vocal', 'url': 'https://www.last.fm/tag/vocal'}, {'count': 2, 'name': 'soul', 'url': 'https://www.last.fm/tag/soul'}, {'count': 2, 'name': 'acoustic', 'url': 'https://www.last.fm/tag/acoustic'}, {'count': 2, 'name': 'Fusion', 'url': 'https://www.last.fm/tag/Fusion'}, {'count': 2, 'name': 'Schlager', 'url': 'https://www.last.fm/tag/Schlager'}, {'count': 2, 'name': 'england', 'url': 'https://www.last.fm/tag/england'}, {'count': 2, 'name': 'covers', 'url': 'https://www.last.fm/tag/covers'}, {'count': 2, 'name': 'comedy', 'url': 'https://www.last.fm/tag/comedy'}, {'count': 2, 'name': 'german', 'url': 'https://www.last.fm/tag/german'}, {'count': 2, 'name': 'vocal harmonies', 'url': 'https://www.last.fm/tag/vocal+harmonies'}, {'count': 2, 'name': "80's", 'url': 'https://www.last.fm/tag/80%27s'}, {'count': 2, 'name': 'Favorite', 'url': 'https://www.last.fm/tag/Favorite'}, {'count': 2, 'name': 'nostalgia', 'url': 'https://www.last.fm/tag/nostalgia'}, {'count': 2, 'name': 'flying', 'url': 'https://www.last.fm/tag/flying'}, {'count': 2, 'name': '80s Pop', 'url': 'https://www.last.fm/tag/80s+Pop'}, {'count': 2, 'name': 'United Kingdom', 'url': 'https://www.last.fm/tag/United+Kingdom'}, {'count': 2, 'name': 'close harmony', 'url': 'https://www.last.fm/tag/close+harmony'}, {'count': 2, 'name': 'cover band', 'url': 'https://www.last.fm/tag/cover+band'}, {'count': 2, 'name': 'acappella', 'url': 'https://www.last.fm/tag/acappella'}, {'count': 2, 'name': 'my loved tracks', 'url': 'https://www.last.fm/tag/my+loved+tracks'}, {'count': 2, 'name': '80er', 'url': 'https://www.last.fm/tag/80er'}, {'count': 2, 'name': 'spotify', 'url': 'https://www.last.fm/tag/spotify'}, {'count': 2, 'name': 'a-capella', 'url': 'https://www.last.fm/tag/a-capella'}, {'count': 2, 'name': 'erotique', 'url': 'https://www.last.fm/tag/erotique'}, {'count': 2, 'name': 'bands I need to check out', 'url': 'https://www.last.fm/tag/bands+I+need+to+check+out'}, {'count': 2, 'name': 'a cappella covers', 'url': 'https://www.last.fm/tag/a+cappella+covers'}, {'count': 2, 'name': 'choice of fristiman', 'url': 'https://www.last.fm/tag/choice+of+fristiman'}, {'count': 2, 'name': 'Top of the world', 'url': 'https://www.last.fm/tag/Top+of+the+world'}, {'count': 2, 'name': 'all-male bands', 'url': 'https://www.last.fm/tag/all-male+bands'}, {'count': 2, 'name': 'beauty and sadness', 'url': 'https://www.last.fm/tag/beauty+and+sadness'}, {'count': 2, 'name': 'poprawiacz nastroju', 'url': 'https://www.last.fm/tag/poprawiacz+nastroju'}, {'count': 2, 'name': 'fave 80s', 'url': 'https://ww ...
# {'toptags': {'tag': [{'count': 100, 'name': 'rock', 'url': 'https://www.last.fm/tag/rock'}, {'count': 86, 'name': 'alternative', 'url': 'https://www.last.fm/tag/alternative'}, {'count': 74, 'name': 'alternative rock', 'url': 'https://www.last.fm/tag/alternative+rock'}, {'count': 50, 'name': 'indie', 'url': 'https://www.last.fm/tag/indie'}, {'count': 41, 'name': 'indie rock', 'url': 'https://www.last.fm/tag/indie+rock'}, {'count': 37, 'name': 'seen live', 'url': 'https://www.last.fm/tag/seen+live'}, {'count': 15, 'name': 'emo', 'url': 'https://www.last.fm/tag/emo'}, {'count': 12, 'name': 'power pop', 'url': 'https://www.last.fm/tag/power+pop'}, {'count': 11, 'name': 'punk', 'url': 'https://www.last.fm/tag/punk'}, {'count': 9, 'name': '90s', 'url': 'https://www.last.fm/tag/90s'}, {'count': 9, 'name': 'weezer', 'url': 'https://www.last.fm/tag/weezer'}, {'count': 8, 'name': 'american', 'url': 'https://www.last.fm/tag/american'}, {'count': 7, 'name': 'geek rock', 'url': 'https://www.last.fm/tag/geek+rock'}, {'count': 6, 'name': 'pop', 'url': 'https://www.last.fm/tag/pop'}, {'count': 5, 'name': 'pop punk', 'url': 'https://www.last.fm/tag/pop+punk'}, {'count': 5, 'name': 'punk rock', 'url': 'https://www.last.fm/tag/punk+rock'}, {'count': 4, 'name': 'pop rock', 'url': 'https://www.last.fm/tag/pop+rock'}, {'count': 4, 'name': 'Nerd Rock', 'url': 'https://www.last.fm/tag/Nerd+Rock'}, {'count': 3, 'name': 'California', 'url': 'https://www.last.fm/tag/California'}, {'count': 3, 'name': 'indie pop', 'url': 'https://www.last.fm/tag/indie+pop'}, {'count': 3, 'name': 'favorites', 'url': 'https://www.last.fm/tag/favorites'}, {'count': 3, 'name': 'USA', 'url': 'https://www.last.fm/tag/USA'}, {'count': 2, 'name': 'Grunge', 'url': 'https://www.last.fm/tag/Grunge'}, {'count': 2, 'name': 'classic rock', 'url': 'https://www.last.fm/tag/classic+rock'}, {'count': 2, 'name': 'los angeles', 'url': 'https://www.last.fm/tag/los+angeles'}, {'count': 2, 'name': 'hard rock', 'url': 'https://www.last.fm/tag/hard+rock'}, {'count': 2, 'name': '00s', 'url': 'https://www.last.fm/tag/00s'}, {'count': 2, 'name': 'metal', 'url': 'https://www.last.fm/tag/metal'}, {'count': 2, 'name': 'college rock', 'url': 'https://www.last.fm/tag/college+rock'}, {'count': 2, 'name': 'Awesome', 'url': 'https://www.last.fm/tag/Awesome'}, {'count': 2, 'name': 'male vocalists', 'url': 'https://www.last.fm/tag/male+vocalists'}, {'count': 2, 'name': 'fun', 'url': 'https://www.last.fm/tag/fun'}, {'count': 2, 'name': 'powerpop', 'url': 'https://www.last.fm/tag/powerpop'}, {'count': 1, 'name': 'geek', 'url': 'https://www.last.fm/tag/geek'}, {'count': 1, 'name': 'Favorite', 'url': 'https://www.last.fm/tag/Favorite'}, {'count': 1, 'name': 'hardcore', 'url': 'https://www.last.fm/tag/hardcore'}, {'count': 1, 'name': 'Love', 'url': 'https://www.last.fm/tag/Love'}, {'count': 1, 'name': 'britpop', 'url': 'https://www.last.fm/tag/britpop'}, {'count': 1, 'name': 'Pop-Rock', 'url': 'https://www.last.fm/tag/Pop-Rock'}], '@attr': {'artist': 'Weezer'}}}
# ...
# {'toptags': {'tag': [{'count': 100, 'name': 'electronica', 'url': 'https://www.last.fm/tag/electronica'}, {'count': 100, 'name': 'Canadian', 'url': 'https://www.last.fm/tag/Canadian'}, {'count': 100, 'name': 'future pop', 'url': 'https://www.last.fm/tag/future+pop'}, {'count': 100, 'name': 'elektro-house', 'url': 'https://www.last.fm/tag/elektro-house'}], '@attr': {'artist': 'Milk '}}}
# {'toptags': {'tag': [{'count': 100, 'name': 'House', 'url': 'https://www.last.fm/tag/House'}, {'count': 100, 'name': 'mexico', 'url': 'https://www.last.fm/tag/mexico'}, {'count': 100, 'name': 'psytrance', 'url': 'https://www.last.fm/tag/psytrance'}, {'count': 100, 'name': 'dj', 'url': 'https://www.last.fm/tag/dj'}, {'count': 100, 'name': 'mexican', 'url': 'https://www.last.fm/tag/mexican'}, {'count': 100, 'name': 'vocal psytrance', 'url': 'https://www.last.fm/tag/vocal+psytrance'}, {'count': 100, 'name': 'neo full-on', 'url': 'https://www.last.fm/tag/neo+full-on'}, {'count': 100, 'name': 'vocal hardstyle', 'url': 'https://www.last.fm/tag/vocal+hardstyle'}], '@attr': {'artist': 'Mariana Bo'}}}
# {'toptags': {'tag': [{'count': 100, 'name': 'soul', 'url': 'https://www.last.fm/tag/soul'}, {'count': 86, 'name': 'seen live', 'url': 'https://www.last.fm/tag/seen+live'}, {'count': 84, 'name': 'Hip-Hop', 'url': 'https://www.last.fm/tag/Hip-Hop'}, {'count': 72, 'name': 'rnb', 'url': 'https://www.last.fm/tag/rnb'}, {'count': 46, 'name': 'Neo-Soul', 'url': 'https://www.last.fm/tag/Neo-Soul'}, {'count': 36, 'name': 'hip hop', 'url': 'https://www.last.fm/tag/hip+hop'}, {'count': 29, 'name': 'american', 'url': 'https://www.last.fm/tag/american'}, {'count': 29, 'name': 'alternative rnb', 'url': 'https://www.last.fm/tag/alternative+rnb'}, {'count': 27, 'name': 'funk', 'url': 'https://www.last.fm/tag/funk'}, {'count': 22, 'name': 'rap', 'url': 'https://www.last.fm/tag/rap'}, {'count': 15, 'name': 'California', 'url': 'https://www.last.fm/tag/California'}, {'count': 12, 'name': 'synth funk', 'url': 'https://www.last.fm/tag/synth+funk'}, {'count': 12, 'name': 'contemporary rnb', 'url': 'https://www.last.fm/tag/contemporary+rnb'}, {'count': 10, 'name': 'Anderson paak', 'url': 'https://www.last.fm/tag/Anderson+paak'}, {'count': 8, 'name': 'USA', 'url': 'https://www.last.fm/tag/USA'}, {'count': 8, 'name': 'underground hip-hop', 'url': 'https://www.last.fm/tag/underground+hip-hop'}, {'count': 8, 'name': 'r&b', 'url': 'https://www.last.fm/tag/r&b'}, {'count': 8, 'name': 'Neo Soul', 'url': 'https://www.last.fm/tag/Neo+Soul'}, {'count': 8, 'name': 'jazz rap', 'url': 'https://www.last.fm/tag/jazz+rap'}, {'count': 8, 'name': 'oxnard', 'url': 'https://www.last.fm/tag/oxnard'}, {'count': 5, 'name': 'electronic', 'url': 'https://www.last.fm/tag/electronic'}, {'count': 5, 'name': 'jazz', 'url': 'https://www.last.fm/tag/jazz'}, {'count': 5, 'name': 'pop', 'url': 'https://www.last.fm/tag/pop'}, {'count': 5, 'name': 'Smooth Soul', 'url': 'https://www.last.fm/tag/Smooth+Soul'}, {'count': 5, 'name': 'psychedelic', 'url': 'https://www.last.fm/tag/psychedelic'}, {'count': 5, 'name': 'synthpop', 'url': 'https://www.last.fm/tag/synthpop'}, {'count': 5, 'name': 'west coast', 'url': 'https://www.last.fm/tag/west+coast'}, {'count': 5, 'name': 'male vocalists', 'url': 'https://www.last.fm/tag/male+vocalists'}, {'count': 5, 'name': 'rhythm and blues', 'url': 'https://www.last.fm/tag/rhythm+and+blues'}, {'count': 5, 'name': 'trap', 'url': 'https://www.last.fm/tag/trap'}, {'count': 5, 'name': '10s', 'url': 'https://www.last.fm/tag/10s'}, {'count': 5, 'name': '2010s', 'url': 'https://www.last.fm/tag/2010s'}, {'count': 5, 'name': 'United States', 'url': 'https://www.last.fm/tag/United+States'}, {'count': 5, 'name': 'All', 'url': 'https://www.last.fm/tag/All'}, {'count': 5, 'name': 'west coast hip hop', 'url': 'https://www.last.fm/tag/west+coast+hip+hop'}, {'count': 3, 'name': 'nu jazz', 'url': 'https://www.last.fm/tag/nu+jazz'}, {'count': 3, 'name': 'indie', 'url': 'https://www.last.fm/tag/indie'}, {'count': 3, 'name': 'Psychedelic Soul', 'url': 'https://www.last.fm/tag/Psychedelic+Soul'}, {'count': 3, 'name': 'romantic', 'url': 'https://www.last.fm/tag/romantic'}, {'count': 3, 'name': 'Energetic', 'url': 'https://www.last.fm/tag/Energetic'}, {'count': 3, 'name': 'Reflective', 'url': 'https://www.last.fm/tag/Reflective'}, {'count': 3, 'name': 'seenlive', 'url': 'https://www.last.fm/tag/seenlive'}, {'count': 3, 'name': 'Nu-Soul', 'url': 'https://www.last.fm/tag/Nu-Soul'}, {'count': 3, 'name': 'nu soul', 'url': 'https://www.last.fm/tag/nu+soul'}, {'count': 3, 'name': 'beats', 'url': 'https://www.last.fm/tag/beats'}, {'count': 3, 'name': 'hypnotic', 'url': 'https://www.last.fm/tag/hypnotic'}, {'count': 3, 'name': 'somber', 'url': 'https://www.last.fm/tag/somber'}, {'count': 3, 'name': 'intimate', 'url': 'https://www.last.fm/tag/intimate'}, {'count': 3, 'name': 'k-pop', 'url': 'https://www.last.fm/tag/k-pop'}, {'count': 3, 'name': 'male vocalist', 'url': 'https://www.last.fm/tag/male+vocalist'}, {'count': 3, 'name': 'yearning', 'url': 'https://www.last.fm/tag/yearning'}, ...
# {'toptags': {'tag': [{'count': 100, 'name': 'rock', 'url': 'https://www.last.fm/tag/rock'}, {'count': 99, 'name': 'pop rock', 'url': 'https://www.last.fm/tag/pop+rock'}, {'count': 94, 'name': 'alternative', 'url': 'https://www.last.fm/tag/alternative'}, {'count': 80, 'name': 'alternative rock', 'url': 'https://www.last.fm/tag/alternative+rock'}, {'count': 62, 'name': 'indie', 'url': 'https://www.last.fm/tag/indie'}, {'count': 21, 'name': 'pop', 'url': 'https://www.last.fm/tag/pop'}, {'count': 12, 'name': 'american', 'url': 'https://www.last.fm/tag/american'}, {'count': 10, 'name': 'piano rock', 'url': 'https://www.last.fm/tag/piano+rock'}, {'count': 9, 'name': 'seen live', 'url': 'https://www.last.fm/tag/seen+live'}, {'count': 8, 'name': 'male vocalists', 'url': 'https://www.last.fm/tag/male+vocalists'}, {'count': 7, 'name': 'OneRepublic', 'url': 'https://www.last.fm/tag/OneRepublic'}, {'count': 5, 'name': 'indie rock', 'url': 'https://www.last.fm/tag/indie+rock'}, {'count': 4, 'name': 'soft rock', 'url': 'https://www.last.fm/tag/soft+rock'}, {'count': 4, 'name': 'Pop-Rock', 'url': 'https://www.last.fm/tag/Pop-Rock'}, {'count': 3, 'name': 'USA', 'url': 'https://www.last.fm/tag/USA'}, {'count': 3, 'name': '00s', 'url': 'https://www.last.fm/tag/00s'}, {'count': 3, 'name': 'One Republic', 'url': 'https://www.last.fm/tag/One+Republic'}, {'count': 2, 'name': 'easy listening', 'url': 'https://www.last.fm/tag/easy+listening'}, {'count': 2, 'name': 'piano', 'url': 'https://www.last.fm/tag/piano'}, {'count': 2, 'name': 'band', 'url': 'https://www.last.fm/tag/band'}, {'count': 2, 'name': 'indie pop', 'url': 'https://www.last.fm/tag/indie+pop'}, {'count': 2, 'name': 'Love', 'url': 'https://www.last.fm/tag/Love'}, {'count': 2, 'name': 'amazing', 'url': 'https://www.last.fm/tag/amazing'}, {'count': 2, 'name': 'Awesome', 'url': 'https://www.last.fm/tag/Awesome'}, {'count': 2, 'name': 'favorites', 'url': 'https://www.last.fm/tag/favorites'}, {'count': 2, 'name': 'Colorado', 'url': 'https://www.last.fm/tag/Colorado'}, {'count': 1, 'name': 'relaxing', 'url': 'https://www.last.fm/tag/relaxing'}, {'count': 1, 'name': 'acoustic', 'url': 'https://www.last.fm/tag/acoustic'}, {'count': 1, 'name': 'emo', 'url': 'https://www.last.fm/tag/emo'}], '@attr': {'artist': 'OneRepublic'}}}
# {'toptags': {'tag': [{'count': 100, 'name': 'Hip-Hop', 'url': 'https://www.last.fm/tag/Hip-Hop'}, {'count': 57, 'name': 'seen live', 'url': 'https://www.last.fm/tag/seen+live'}, {'count': 53, 'name': 'rap', 'url': 'https://www.last.fm/tag/rap'}, {'count': 36, 'name': 'underground hip-hop', 'url': 'https://www.last.fm/tag/underground+hip-hop'}, {'count': 28, 'name': 'hip hop', 'url': 'https://www.last.fm/tag/hip+hop'}, {'count': 20, 'name': 'underground rap', 'url': 'https://www.last.fm/tag/underground+rap'}, {'count': 9, 'name': 'hardcore hip-hop', 'url': 'https://www.last.fm/tag/hardcore+hip-hop'}, {'count': 7, 'name': 'experimental hip-hop', 'url': 'https://www.last.fm/tag/experimental+hip-hop'}, {'count': 7, 'name': 'american', 'url': 'https://www.last.fm/tag/american'}, {'count': 7, 'name': 'hardcore hip hop', 'url': 'https://www.last.fm/tag/hardcore+hip+hop'}, {'count': 5, 'name': 'alternative hip-hop', 'url': 'https://www.last.fm/tag/alternative+hip-hop'}, {'count': 5, 'name': 'alternative rap', 'url': 'https://www.last.fm/tag/alternative+rap'}, {'count': 4, 'name': 'USA', 'url': 'https://www.last.fm/tag/USA'}, {'count': 4, 'name': 'experimental hip hop', 'url': 'https://www.last.fm/tag/experimental+hip+hop'}, {'count': 3, 'name': 'experimental', 'url': 'https://www.last.fm/tag/experimental'}, {'count': 3, 'name': 'underground hip hop', 'url': 'https://www.last.fm/tag/underground+hip+hop'}, {'count': 3, 'name': 'Political Hip Hop', 'url': 'https://www.last.fm/tag/Political+Hip+Hop'}, {'count': 3, 'name': 'electronic', 'url': 'https://www.last.fm/tag/electronic'}, {'count': 2, 'name': 'el-p', 'url': 'https://www.last.fm/tag/el-p'}, {'count': 2, 'name': 'hiphop', 'url': 'https://www.last.fm/tag/hiphop'}, {'count': 2, 'name': 'underground', 'url': 'https://www.last.fm/tag/underground'}, {'count': 2, 'name': 'male vocalists', 'url': 'https://www.last.fm/tag/male+vocalists'}, {'count': 2, 'name': '10s', 'url': 'https://www.last.fm/tag/10s'}, {'count': 2, 'name': 'United States', 'url': 'https://www.last.fm/tag/United+States'}, {'count': 2, 'name': 'All', 'url': 'https://www.last.fm/tag/All'}, {'count': 2, 'name': 'boom bap', 'url': 'https://www.last.fm/tag/boom+bap'}, {'count': 2, 'name': 'alternative hip hop', 'url': 'https://www.last.fm/tag/alternative+hip+hop'}, {'count': 2, 'name': 'political hip-hop', 'url': 'https://www.last.fm/tag/political+hip-hop'}, {'count': 2, 'name': 'killer mike', 'url': 'https://www.last.fm/tag/killer+mike'}, {'count': 2, 'name': 'real bad guy shit', 'url': 'https://www.last.fm/tag/real+bad+guy+shit'}], '@attr': {'artist': 'Run the Jewels'}}}
# {'toptags': {'tag': [{'count': 100, 'name': 'electronica', 'url': 'https://www.last.fm/tag/electronica'}, {'count': 100, 'name': 'pop', 'url': 'https://www.last.fm/tag/pop'}, {'count': 100, 'name': 'morocco', 'url': 'https://www.last.fm/tag/morocco'}, {'count': 100, 'name': 'abba', 'url': 'https://www.last.fm/tag/abba'}], '@attr': {'artist': 'Ily'}}}
# {'toptags': {'tag': [{'count': 100, 'name': 'Hip-Hop', 'url': 'https://www.last.fm/tag/Hip-Hop'}, {'count': 100, 'name': 'chillout', 'url': 'https://www.last.fm/tag/chillout'}, {'count': 100, 'name': 'jazz', 'url': 'https://www.last.fm/tag/jazz'}, {'count': 100, 'name': 'Lo-Fi', 'url': 'https://www.last.fm/tag/Lo-Fi'}, {'count': 100, 'name': 'free', 'url': 'https://www.last.fm/tag/free'}, {'count': 100, 'name': 'Avant-Garde', 'url': 'https://www.last.fm/tag/Avant-Garde'}], '@attr': {'artist': 'Lofi'}}}
# {'toptags': {'tag': [{'count': 100, 'name': 'pop', 'url': 'https://www.last.fm/tag/pop'}, {'count': 88, 'name': '80s', 'url': 'https://www.last.fm/tag/80s'}, {'count': 83, 'name': 'rock', 'url': 'https://www.last.fm/tag/rock'}, {'count': 79, 'name': 'soft rock', 'url': 'https://www.last.fm/tag/soft+rock'}, {'count': 43, 'name': 'chris norman', 'url': 'https://www.last.fm/tag/chris+norman'}, {'count': 20, 'name': 'male vocalists', 'url': 'https://www.last.fm/tag/male+vocalists'}, {'count': 15, 'name': 'british', 'url': 'https://www.last.fm/tag/british'}, {'count': 11, 'name': 'seen live', 'url': 'https://www.last.fm/tag/seen+live'}, {'count': 11, 'name': 'pop rock', 'url': 'https://www.last.fm/tag/pop+rock'}, {'count': 10, 'name': 'classic rock', 'url': 'https://www.last.fm/tag/classic+rock'}, {'count': 7, 'name': 'Smokie', 'url': 'https://www.last.fm/tag/Smokie'}, {'count': 5, 'name': 'suzi quatro', 'url': 'https://www.last.fm/tag/suzi+quatro'}, {'count': 4, 'name': 'Disco', 'url': 'https://www.last.fm/tag/Disco'}, {'count': 4, 'name': 'male vocalist', 'url': 'https://www.last.fm/tag/male+vocalist'}, {'count': 4, 'name': 'music of my childhood', 'url': 'https://www.last.fm/tag/music+of+my+childhood'}, {'count': 3, 'name': 'instrumental', 'url': 'https://www.last.fm/tag/instrumental'}, {'count': 3, 'name': 'alternative', 'url': 'https://www.last.fm/tag/alternative'}, {'count': 3, 'name': 'singer-songwriter', 'url': 'https://www.last.fm/tag/singer-songwriter'}, {'count': 3, 'name': 'UK', 'url': 'https://www.last.fm/tag/UK'}, {'count': 3, 'name': 'romantic', 'url': 'https://www.last.fm/tag/romantic'}, {'count': 3, 'name': 'flute', 'url': 'https://www.last.fm/tag/flute'}, {'count': 3, 'name': 'england', 'url': 'https://www.last.fm/tag/england'}, {'count': 3, 'name': 'celtic', 'url': 'https://www.last.fm/tag/celtic'}, {'count': 3, 'name': 'Pop-Rock', 'url': 'https://www.last.fm/tag/Pop-Rock'}, {'count': 3, 'name': 'english', 'url': 'https://www.last.fm/tag/english'}, {'count': 3, 'name': 'Bands I have seen live', 'url': 'https://www.last.fm/tag/Bands+I+have+seen+live'}, {'count': 3, 'name': '80er Pop', 'url': 'https://www.last.fm/tag/80er+Pop'}, {'count': 3, 'name': 'Soft Rock Oldies', 'url': 'https://www.last.fm/tag/Soft+Rock+Oldies'}, {'count': 2, 'name': 'electronic', 'url': 'https://www.last.fm/tag/electronic'}, {'count': 2, 'name': 'electronica', 'url': 'https://www.last.fm/tag/electronica'}, {'count': 2, 'name': 'classic', 'url': 'https://www.last.fm/tag/classic'}, {'count': 2, 'name': 'hard rock', 'url': 'https://www.last.fm/tag/hard+rock'}, {'count': 2, 'name': 'christmas', 'url': 'https://www.last.fm/tag/christmas'}, {'count': 2, 'name': 'blues', 'url': 'https://www.last.fm/tag/blues'}, {'count': 2, 'name': 'Canadian', 'url': 'https://www.last.fm/tag/Canadian'}, {'count': 2, 'name': 'Drum and bass', 'url': 'https://www.last.fm/tag/Drum+and+bass'}, {'count': 2, 'name': 'xmas', 'url': 'https://www.last.fm/tag/xmas'}, {'count': 2, 'name': 'oldies', 'url': 'https://www.last.fm/tag/oldies'}, {'count': 2, 'name': 'new', 'url': 'https://www.last.fm/tag/new'}, {'count': 2, 'name': 'ballads', 'url': 'https://www.last.fm/tag/ballads'}, {'count': 2, 'name': 'United Kingdom', 'url': 'https://www.last.fm/tag/United+Kingdom'}, {'count': 2, 'name': 'Myjukebox', 'url': 'https://www.last.fm/tag/Myjukebox'}, {'count': 2, 'name': 'All', 'url': 'https://www.last.fm/tag/All'}, {'count': 2, 'name': 'Ciara', 'url': 'https://www.last.fm/tag/Ciara'}, {'count': 2, 'name': 'weihnacht', 'url': 'https://www.last.fm/tag/weihnacht'}, {'count': 2, 'name': 'iskelma', 'url': 'https://www.last.fm/tag/iskelma'}, {'count': 2, 'name': 'GB', 'url': 'https://www.last.fm/tag/GB'}, {'count': 2, 'name': "Destiny's Child", 'url': 'https://www.last.fm/tag/Destiny%27s+Child'}, {'count': 2, 'name': 'Great Britain', 'url': 'https://www.last.fm/tag/Great+Britain'}, {'count': 2, 'name': 'tanzmusik', 'url': 'https://www.last.fm/tag/tanzmusik'}, {'count': 2, 'name': 'EN', ' ...

# %%
df = pd.read_csv(LastFMAPI.FILE_NAME)
df.head()
# Out:
#    Unnamed: 0 track_name    artist album_name       date_listened         uts  \
# 0           0  Untouched  SilenCee  Untouched  07 Dec 2022, 09:30  1670405412
# 1           1      maria     Malte      maria  07 Dec 2022, 09:18  1670404731
# 2           2  let me go     Malte  let me go  07 Dec 2022, 09:16  1670404596
# 3           3    So What       mqx    So What  07 Dec 2022, 09:14  1670404473
# 4           4      maria     Malte      maria  07 Dec 2022, 09:11  1670404288
#
#                                               url        tags
# 0  https://www.last.fm/music/SilenCee/_/Untouched  electronic
# 1         https://www.last.fm/music/Malte/_/maria      german
# 2     https://www.last.fm/music/Malte/_/let+me+go      german
# 3         https://www.last.fm/music/mqx/_/So+What   hardstyle
# 4         https://www.last.fm/music/Malte/_/maria      german

# %%
df.tail()
# Out:
#        Unnamed: 0                                track_name         artist  \
# 18553       18553                    Slippery People - Live  Talking Heads
# 18554       18554                               Found a Job  Talking Heads
# 18555       18555  Thank You for Sending Me an Angel - Live  Talking Heads
# 18556       18556                             Heaven - Live  Talking Heads
# 18557       18557                      Psycho Killer - live  Talking Heads
#
#                      album_name       date_listened         uts  \
# 18553  Stop Making Sense (Live)  07 Aug 2024, 21:15  1723065315
# 18554  Stop Making Sense (Live)  07 Aug 2024, 21:12  1723065120
# 18555  Stop Making Sense (Live)  07 Aug 2024, 21:09  1723064990
# 18556  Stop Making Sense (Live)  07 Aug 2024, 21:06  1723064770
# 18557  Stop Making Sense (Live)  07 Aug 2024, 21:01  1723064494
#
#                                                      url      tags
# 18553  https://www.last.fm/music/Talking+Heads/_/Slip...  new wave
# 18554  https://www.last.fm/music/Talking+Heads/_/Foun...  new wave
# 18555  https://www.last.fm/music/Talking+Heads/_/Than...  new wave
# 18556  https://www.last.fm/music/Talking+Heads/_/Heav...  new wave
# 18557  https://www.last.fm/music/Talking+Heads/_/Psyc...  new wave
